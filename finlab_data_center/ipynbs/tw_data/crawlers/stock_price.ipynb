# %%
import pandas as pd
from io import StringIO
import requests
import datetime
from etl.utils import year_transfer, last_month, char_filter, symbols_change, url_month
from etl.import_sql import *
from tw_data.models import *
import time
import json
import numpy as np
import sys,os
sys.path.append("..")
import django
django.setup()
from django.conf import settings
import logging
import datetime

logging.basicConfig(level=logging.INFO)

# %%
class StockPriceCrawlerTW:
    def __init__(self, date):
        self.date = date
        self.date_str = date.strftime("%Y%m%d")
        self.target_name = "台股每日交易資訊"
        self.sub_market = ["sii", "otc", "rotc"]

    def crawl_sii(self):
        r = requests.post(
            "http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=" + self.date_str + "&type=ALLBUT0999")
        content = r.text.replace("=", "")
        lines = content.split("\n")
        lines = list(filter(lambda l: len(l.split('",')) > 10, lines))
        content = "\n".join(lines)
        if content == "":
            return None
        df = pd.read_csv(StringIO(content))
        df = df.astype(str)
        df = df.apply(lambda s: s.str.replace(",", ""))
        df.iloc[:, 2:] = df.iloc[:, 2:].apply(lambda s: pd.to_numeric(s, errors="coerce"))
        df["date"] = pd.to_datetime(self.date)
        df = df[["證券代號", "date", "證券名稱", "成交股數", "成交筆數", "成交金額", "開盤價", "收盤價", "最高價", "最低價", "最後揭示買價", "最後揭示賣價"]]

        df = df.rename(columns={"證券代號": "stock_id", "證券名稱": "stock_name",
                                "成交股數": "vol", "成交金額": "turnover_price",
                                "開盤價": "open", "收盤價": "close",
                                "最高價": "high", "最低價": "low", "成交筆數": "transactions_number",
                                "最後揭示買價": "finally_reveal_buy_price", "最後揭示賣價": "finally_reveal_sell_price"})
        return df

    @staticmethod
    def select_otc_id(code):
        if len(code) > 5:
            if code[-1] == "P":
                return False
            else:
                try:
                    code = int(code[:5])
                    if code > 10000:
                        return False
                    else:
                        return True
                except ValueError:
                    return True
        else:
            return True

    def crawl_otc(self):
        y = str(int(self.date.strftime("%Y")) - 1911)
        date_str = y + "/" + self.date.strftime("%m") + "/" + self.date.strftime("%d")
        link = "http://www.tpex.org.tw/web/stock/aftertrading/daily_close_quotes/stk_quote_download.php?l=zh-tw&d=" \
               + date_str + "&s=0,asc,0"
        r = requests.get(link)
        lines = r.text.replace("\r", "").split("\n")
        try:
            df = pd.read_csv(StringIO("\n".join(lines[3:])), header=None)
            df = df.astype(str)
        except pd.errors.ParserError:
            return None
        df.columns = list(map(lambda s: s.replace(" ", ""), lines[2].split(",")))
        df = df.apply(lambda s: s.str.replace(",", ""))
        df["stock_id"] = df["代號"]
        df["代號"] = df["代號"].apply(lambda s: self.select_otc_id(s))
        df = df[df["代號"]]
        df["date"] = pd.to_datetime(self.date)
        df = df[["stock_id", "date", "名稱", "成交股數", "成交金額(元)", "開盤", "收盤", "最高", "最低", "成交筆數", "最後買價", "最後賣價"]]
        df = df.rename(columns={"名稱": "stock_name",
                                "成交股數": "vol", "成交金額(元)": "turnover_price",
                                "開盤": "open", "收盤": "close",
                                "最高": "high", "最低": "low", "成交筆數": "transactions_number",
                                "最後買價": "finally_reveal_buy_price", "最後賣價": "finally_reveal_sell_price"})
        df.iloc[:, 3:] = df.iloc[:, 3:].apply(lambda s: pd.to_numeric(s, errors="coerce"))
        df = df.dropna(thresh=7)
        return df

    def crawl_rotc(self):
        link = "http://www.tpex.org.tw/web/emergingstock/historical/daily/EMDaily_dl.php?l=zh-tw&f=EMdes010." + \
               self.date_str + "-C.csv"
        r = requests.get(link)
        lines = r.text.replace("\r", "").split("\n")
        try:
            columns_line = lines[3]
        except IndexError:
            return None
        lines = list(filter(lambda l: len(l.split('",')) > 10, lines))
        try:
            df = pd.read_csv(StringIO("\n".join(lines)), header=None)
        except pd.errors.EmptyDataError:
            return None
        df.columns = list(map(lambda l: l.replace(" ", ""), columns_line.split(",")))
        df = df.astype(str)
        df = df.apply(lambda s: s.str.replace(",", ""))
        df["date"] = pd.to_datetime(self.date)
        if "證券名稱" not in df.columns:
            df = df.rename(columns={"名稱": "證券名稱"})
            df['最後最佳報買價']=None
            df['最後最佳報賣價']=None

        df = df[["證券代號", "date", "證券名稱", "成交量", "成交金額", "前日均價", "最後", "最高", "最低", "日均價", "筆數", "最後最佳報買價", "最後最佳報賣價"]]
        df = df.rename(columns={"證券代號": "stock_id", "證券名稱": "stock_name",
                                "成交量": "vol", "成交金額": "turnover_price",
                                "前日均價": "open", "最後": "close",
                                "最高": "high", "最低": "low",
                                "日均價": "mean_price", "筆數": "transactions_number",
                                "最後最佳報買價": "finally_reveal_buy_price", "最後最佳報賣價": "finally_reveal_sell_price"})
        df.iloc[:, 3:] = df.iloc[:, 3:].apply(lambda s: pd.to_numeric(s, errors="coerce"))
        df['stock_id'] = df['stock_id'].apply(lambda s: s[:s.index('  ')] if '  ' in s else s)
        df['stock_name'] = df['stock_name'].apply(lambda s: s[:s.index('  ')] if '  ' in s else s)
        df = df[df["stock_id"] != "合計"]
        return df

    def crawl_main(self):
        try:
            df = pd.concat([self.crawl_sii(), self.crawl_otc()])
        except ValueError:
            return None
        return df

# %%
import datetime
date=datetime.datetime(2007,1,25)
c=StockPriceCrawlerTW(date)
cc=c.crawl_rotc()
cc

# %%
C1=CrawlerProcess(StockPriceCrawlerTW,'crawl_rotc' ,RotcStockPrice,'date_range')
logging.info(C1)

# # 指定日期區間爬蟲
# C1.specified_date_crawl('2007-1-4','2007-1-5')

# 自動爬蟲
C1.auto_update_crawl()
# Out:
# INFO:root:rotc_stock_price
# table_earliest_date:2007-01-04 00:00:00
# table_latest_date:2020-07-21 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-22 to 2020-07-22 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-22 to 2020-07-22 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-22 00:00:00 to 2020-07-22 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-23 to 2020-07-23 bulk_create:250
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-23 to 2020-07-23 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-23 00:00:00 to 2020-07-23 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-24 to 2020-07-24 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-24 to 2020-07-24 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-24 00:00:00 to 2020-07-24 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-07-25 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-07-26 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-27 to 2020-07-27 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-27 to 2020-07-27 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-27 00:00:00 to 2020-07-27 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-28 to 2020-07-28 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-28 to 2020-07-28 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-28 00:00:00 to 2020-07-28 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-29 to 2020-07-29 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-29 to 2020-07-29 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-29 00:00:00 to 2020-07-29 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-30 to 2020-07-30 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-30 to 2020-07-30 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-30 00:00:00 to 2020-07-30 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-31 to 2020-07-31 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-07-31 to 2020-07-31 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-07-31 00:00:00 to 2020-07-31 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-08-01 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-08-02 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-03 to 2020-08-03 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-03 to 2020-08-03 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-03 00:00:00 to 2020-08-03 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-04 to 2020-08-04 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-04 to 2020-08-04 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-04 00:00:00 to 2020-08-04 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-05 to 2020-08-05 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-05 to 2020-08-05 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-05 00:00:00 to 2020-08-05 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-06 to 2020-08-06 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-06 to 2020-08-06 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-06 00:00:00 to 2020-08-06 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-07 to 2020-08-07 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-07 to 2020-08-07 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-07 00:00:00 to 2020-08-07 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-08-08 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-08-09 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-10 to 2020-08-10 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-10 to 2020-08-10 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-10 00:00:00 to 2020-08-10 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-11 to 2020-08-11 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-11 to 2020-08-11 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-11 00:00:00 to 2020-08-11 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-12 to 2020-08-12 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-12 to 2020-08-12 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-12 00:00:00 to 2020-08-12 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-13 to 2020-08-13 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-13 to 2020-08-13 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-13 00:00:00 to 2020-08-13 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-14 to 2020-08-14 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-14 to 2020-08-14 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-14 00:00:00 to 2020-08-14 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-08-15 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-08-16 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-17 to 2020-08-17 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-17 to 2020-08-17 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-17 00:00:00 to 2020-08-17 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-18 to 2020-08-18 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-18 to 2020-08-18 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-18 00:00:00 to 2020-08-18 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-19 to 2020-08-19 bulk_create:250
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-19 to 2020-08-19 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-19 00:00:00 to 2020-08-19 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-20 to 2020-08-20 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-20 to 2020-08-20 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-20 00:00:00 to 2020-08-20 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-21 to 2020-08-21 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-21 to 2020-08-21 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-21 00:00:00 to 2020-08-21 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-08-22 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-08-23 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-24 to 2020-08-24 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-24 to 2020-08-24 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-24 00:00:00 to 2020-08-24 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-25 to 2020-08-25 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-25 to 2020-08-25 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-25 00:00:00 to 2020-08-25 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-26 to 2020-08-26 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-26 to 2020-08-26 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-26 00:00:00 to 2020-08-26 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-27 to 2020-08-27 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-27 to 2020-08-27 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-27 00:00:00 to 2020-08-27 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-28 to 2020-08-28 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-28 to 2020-08-28 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-28 00:00:00 to 2020-08-28 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-08-29 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-08-30 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-31 to 2020-08-31 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-08-31 to 2020-08-31 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-08-31 00:00:00 to 2020-08-31 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-01 to 2020-09-01 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-01 to 2020-09-01 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-01 00:00:00 to 2020-09-01 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-02 to 2020-09-02 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-02 to 2020-09-02 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-02 00:00:00 to 2020-09-02 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-03 to 2020-09-03 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-03 to 2020-09-03 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-03 00:00:00 to 2020-09-03 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-04 to 2020-09-04 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-04 to 2020-09-04 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-04 00:00:00 to 2020-09-04 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-09-05 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-09-06 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-07 to 2020-09-07 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-07 to 2020-09-07 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-07 00:00:00 to 2020-09-07 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-08 to 2020-09-08 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-08 to 2020-09-08 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-08 00:00:00 to 2020-09-08 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-09 to 2020-09-09 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-09 to 2020-09-09 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-09 00:00:00 to 2020-09-09 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-10 to 2020-09-10 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-10 to 2020-09-10 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-10 00:00:00 to 2020-09-10 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-11 to 2020-09-11 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-11 to 2020-09-11 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-11 00:00:00 to 2020-09-11 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-09-12 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-09-13 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-14 to 2020-09-14 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-14 to 2020-09-14 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-14 00:00:00 to 2020-09-14 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-15 to 2020-09-15 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-15 to 2020-09-15 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-15 00:00:00 to 2020-09-15 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-16 to 2020-09-16 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-16 to 2020-09-16 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-16 00:00:00 to 2020-09-16 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-17 to 2020-09-17 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-17 to 2020-09-17 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-17 00:00:00 to 2020-09-17 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-18 to 2020-09-18 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-18 to 2020-09-18 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-18 00:00:00 to 2020-09-18 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-09-19 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-09-20 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-21 to 2020-09-21 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-21 to 2020-09-21 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-21 00:00:00 to 2020-09-21 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-22 to 2020-09-22 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-22 to 2020-09-22 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-22 00:00:00 to 2020-09-22 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-23 to 2020-09-23 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-23 to 2020-09-23 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-23 00:00:00 to 2020-09-23 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-24 to 2020-09-24 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-24 to 2020-09-24 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-24 00:00:00 to 2020-09-24 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-25 to 2020-09-25 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-25 to 2020-09-25 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-25 00:00:00 to 2020-09-25 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-09-26 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-09-27 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-28 to 2020-09-28 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-28 to 2020-09-28 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-28 00:00:00 to 2020-09-28 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-29 to 2020-09-29 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-29 to 2020-09-29 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-29 00:00:00 to 2020-09-29 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-30 to 2020-09-30 bulk_create:246
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-09-30 to 2020-09-30 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-09-30 00:00:00 to 2020-09-30 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-10-01 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-02 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-03 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-04 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-05 to 2020-10-05 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-05 to 2020-10-05 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-05 00:00:00 to 2020-10-05 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-06 to 2020-10-06 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-06 to 2020-10-06 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-06 00:00:00 to 2020-10-06 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-07 to 2020-10-07 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-07 to 2020-10-07 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-07 00:00:00 to 2020-10-07 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-08 to 2020-10-08 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-08 to 2020-10-08 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-08 00:00:00 to 2020-10-08 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-10-09 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-10 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-11 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-12 to 2020-10-12 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-12 to 2020-10-12 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-12 00:00:00 to 2020-10-12 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-13 to 2020-10-13 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-13 to 2020-10-13 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-13 00:00:00 to 2020-10-13 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-14 to 2020-10-14 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-14 to 2020-10-14 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-14 00:00:00 to 2020-10-14 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-15 to 2020-10-15 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-15 to 2020-10-15 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-15 00:00:00 to 2020-10-15 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-16 to 2020-10-16 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-16 to 2020-10-16 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-16 00:00:00 to 2020-10-16 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-10-17 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-18 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-19 to 2020-10-19 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-19 to 2020-10-19 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-19 00:00:00 to 2020-10-19 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-20 to 2020-10-20 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-20 to 2020-10-20 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-20 00:00:00 to 2020-10-20 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-21 to 2020-10-21 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-21 to 2020-10-21 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-21 00:00:00 to 2020-10-21 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-22 to 2020-10-22 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-22 to 2020-10-22 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-22 00:00:00 to 2020-10-22 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-23 to 2020-10-23 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-23 to 2020-10-23 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-23 00:00:00 to 2020-10-23 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-10-24 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-10-25 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-26 to 2020-10-26 bulk_create:245
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-26 to 2020-10-26 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-26 00:00:00 to 2020-10-26 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-27 to 2020-10-27 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-27 to 2020-10-27 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-27 00:00:00 to 2020-10-27 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-28 to 2020-10-28 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-28 to 2020-10-28 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-28 00:00:00 to 2020-10-28 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-29 to 2020-10-29 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-29 to 2020-10-29 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-29 00:00:00 to 2020-10-29 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-30 to 2020-10-30 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-10-30 to 2020-10-30 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-10-30 00:00:00 to 2020-10-30 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-10-31 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-11-01 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-02 to 2020-11-02 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-02 to 2020-11-02 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-02 00:00:00 to 2020-11-02 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-03 to 2020-11-03 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-03 to 2020-11-03 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-03 00:00:00 to 2020-11-03 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-04 to 2020-11-04 bulk_create:247
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-04 to 2020-11-04 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-04 00:00:00 to 2020-11-04 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-05 to 2020-11-05 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-05 to 2020-11-05 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-05 00:00:00 to 2020-11-05 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-06 to 2020-11-06 bulk_create:248
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-06 to 2020-11-06 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-06 00:00:00 to 2020-11-06 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-11-07 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-11-08 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-09 to 2020-11-09 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-09 to 2020-11-09 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-09 00:00:00 to 2020-11-09 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-10 to 2020-11-10 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-10 to 2020-11-10 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-10 00:00:00 to 2020-11-10 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-11 to 2020-11-11 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-11 to 2020-11-11 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-11 00:00:00 to 2020-11-11 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-12 to 2020-11-12 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-12 to 2020-11-12 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-12 00:00:00 to 2020-11-12 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-13 to 2020-11-13 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-13 to 2020-11-13 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-13 00:00:00 to 2020-11-13 00:00:00
# ERROR:etl.import_sql:Fail!check if 2020-11-14 00:00:00 is a holiday
# ERROR:etl.import_sql:Fail!check if 2020-11-15 00:00:00 is a holiday
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-16 to 2020-11-16 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-16 to 2020-11-16 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-16 00:00:00 to 2020-11-16 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-17 to 2020-11-17 bulk_create:249
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-17 to 2020-11-17 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-17 00:00:00 to 2020-11-17 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-18 to 2020-11-18 bulk_create:250
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-18 to 2020-11-18 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-18 00:00:00 to 2020-11-18 00:00:00
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-19 to 2020-11-19 bulk_create:251
# INFO:etl.import_sql:Finish!<class 'tw_data.models.RotcStockPrice'> date:from 2020-11-19 to 2020-11-19 bulk_update:0
# INFO:etl.import_sql:Finish!download data from 2020-11-19 00:00:00 to 2020-11-19 00:00:00
# 'Finish!download data from 2020-07-22 00:00:00 to 2020-11-19 00:00:00'
